# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset_company_job roles.csv')
df.head()
# Out:
#   Company                   Job Role  \
# 0  Google               Data Analyst
# 1  Google          Backend Developer
# 2  Google                AI Engineer
# 3  Google  Machine Learning Engineer
# 4  Google            DevOps Engineer
#
#                                        Skills Needed
# 0  SQL, Excel, Python, Power BI, Tableau, Data Cl...
# 1  Python, Java, Node.js, APIs, Databases, System...
# 2  Python, Deep Learning, NLP, TensorFlow, PyTorc...
# 3  Python, Scikit-learn, ML Algorithms, Model Dep...
# 4   Docker, Kubernetes, CI/CD, AWS, Linux, Terraform

# %%
len(df['Company'])
# Out:
# 170

# %%
df.shape
# Out:
# (170, 3)

# %%
df['Company'].unique()
# Out:
# array(['Google', 'Microsoft', 'Amazon', 'Meta', 'Apple', 'NVIDIA', 'IBM',
#        'Oracle', 'Accenture', 'TCS', 'Infosys', 'Wipro', 'Capgemini',
#        'Deloitte', 'Flipkart', 'Uber', 'Airbnb'], dtype=object)

# %%
df['Job Role'].unique()
# Out:
# array(['Data Analyst', 'Backend Developer', 'AI Engineer',
#        'Machine Learning Engineer', 'DevOps Engineer', 'Cloud Engineer',
#        'Business Analyst', 'Data Scientist', 'Software Engineer',
#        'Cybersecurity Analyst'], dtype=object)

# %%
df['Skills Needed'].value_counts()
# Out:
# Skills Needed
# SQL, Excel, Python, Power BI, Tableau, Data Cleaning                          17
# Python, Java, Node.js, APIs, Databases, System Design                         17
# Python, Deep Learning, NLP, TensorFlow, PyTorch, LLMs                         17
# Python, Scikit-learn, ML Algorithms, Model Deployment, Feature Engineering    17
# Docker, Kubernetes, CI/CD, AWS, Linux, Terraform                              17
# AWS, Azure, GCP, Networking, Infrastructure as Code                           17
# Excel, SQL, Stakeholder Communication, Requirement Analysis                   17
# Python, Statistics, Machine Learning, Data Visualization                      17
# Java, C++, Data Structures, Algorithms, System Design                         17
# Network Security, SIEM, Ethical Hacking, Risk Analysis                        17
# Name: count, dtype: int64
