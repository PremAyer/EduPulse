# %%
import pandas as pd

# %%
df = pd.read_excel('Company Final Dataset.xlsx')
df.head()
# Out:
#   Company Name                       Job Role  \
# 0     Flipkart       Customer Success Manager
# 1        Cisco      Machine Learning Engineer
# 2          AMD  Business Intelligence Analyst
# 3        Cisco              Financial Analyst
# 4      Siemens           Blockchain Developer
#
#                                      Required Skills
# 0  Java, Machine Learning, SEM, HTML, Ethical Hac...
# 1  Data Visualization, Java, NLP, UX Research, Ta...
# 2  R, Financial Modeling, Blockchain, HTML, Deep ...
# 3  UI Design, Solidity, Tableau, Blockchain, Azur...
# 4  Automation, Digital Marketing, Docker, Java, W...

# %%
len(df['Company Name'])
# Out:
# 2200

# %%
df.shape
# Out:
# (2200, 3)

# %%
df['Company Name'].unique()
# Out:
# array(['Flipkart', 'Cisco', 'AMD', 'Siemens', 'ByteDance', 'Qualcomm',
#        'Barclays', 'Uber', 'PwC', 'Bain & Company', 'JP Morgan Chase',
#        'BlackRock', 'Zomato', 'KPMG', 'Stripe', 'PayPal', 'Honeywell',
#        'Atlassian', 'BCG', 'Intel', 'Oracle', 'Salesforce', 'NVIDIA',
#        'Samsung Electronics', 'LG Electronics', 'Databricks', 'Razorpay',
#        'McKinsey', 'EY', 'Workday', 'ServiceNow', 'Twilio',
#        'Morgan Stanley', '3M', 'Shopify', 'Palantir', 'Airbnb', 'Adobe',
#        'SpaceX', 'HSBC', 'Swiggy', 'SAP', 'Tesla', 'Bosch',
#        'Goldman Sachs', 'Zoom', 'VMware', 'ASML', 'Snowflake',
#        'Deloitte India', "BYJU'S", 'Dropbox', 'Cohere', 'Noise',
#        'Hugging Face', 'Mu Sigma', 'Meesho', 'CRED', 'Nomura',
#        'Tiger Analytics', 'Birlasoft', 'Fractal Analytics',
#        'Infosys Finacle', 'Fastly', 'PhonePe', 'Mphasis', 'EY India',
#        'Unacademy', 'L&T Technology Services', 'Cloudflare',
# ...

# %%
df['Company Name'].value_counts()
# Out:
# Company Name
# Uber              40
# Mindtree          32
# InMobi            32
# Qualcomm          31
# PolicyBazaar      31
#                   ..
# Freshworks        13
# Bain & Company    13
# VMware            13
# Groww             12
# Salesforce        11
# Name: count, Length: 103, dtype: int64

# %%
df['Job Role'].unique()
# Out:
# array(['Customer Success Manager', 'Machine Learning Engineer',
#        'Business Intelligence Analyst', 'Financial Analyst',
#        'Blockchain Developer', 'Cybersecurity Analyst', 'AR/VR Developer',
#        'Game Developer', 'Quantitative Analyst', 'Growth Hacker',
#        'DevOps Engineer', 'UI/UX Designer', 'Supply Chain Analyst',
#        'Network Engineer', 'Embedded Systems Engineer',
#        'Cloud Solutions Architect', 'Operations Manager',
#        'Product Manager', 'Full Stack Developer',
#        'HR Analytics Specialist', 'Mobile App Developer',
#        'QA Automation Engineer', 'Data Scientist', 'Systems Analyst',
#        'Risk Analyst', 'Digital Marketing Manager',
#        'Technical Program Manager', 'Robotics Engineer',
#        'Site Reliability Engineer', 'Database Administrator',
#        'AI Research Scientist', 'Autonomous Systems Engineer',
#        'Build Engineer', 'AI Ethics Researcher', 'HR Tech Analyst',
# ...

# %%
df['Required Skills'].value_counts()
# Out:
# Required Skills
# Java, Machine Learning, SEM, HTML, Ethical Hacking, System Design, Microservices, Kubernetes                                             1
# AWS, Shell Scripting, Financial Modeling, Agile, Linux, Python, NoSQL, Computer Vision, Selenium, Microservices, Scikit-learn, Kanban    1
# Azure, GCP, Git, Power BI, Distributed Systems, Scikit-learn, Shell Scripting                                                            1
# Kubernetes, A/B Testing, Tableau, Terraform, Rust, Figma, C++, Kanban                                                                    1
# Selenium, Power BI, Cybersecurity, Go, Financial Modeling, Smart Contracts                                                               1
#                                                                                                                                         ..
# ...
