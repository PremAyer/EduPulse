# %%
import pandas as pd

# %%
# Load the raw dataset
df = pd.read_csv(r'C:\Users\hp\Downloads\EduPulse\data\Optimized Students Placement Dataset.csv')
df.head(5)
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0              10                     3           90.000000  ...
# 1               4                     6           95.000000  ...
# 2               1                     1           83.577184  ...
# 3               2                     2           95.000000  ...
# 4               5                     3           93.738573  ...
#
#    mock_interview_score  attendance_percentage  backlogs  \
# 0             98.676800              77.463863         2
# ...

# %%
essential_columns = [
    'cgpa', 'internships_count', 'projects_count', 'coding_skill_score', 
    'aptitude_score', 'communication_skill_score', 'extracurricular_score', 
    'backlogs', 'placement_status', 'salary_package_lpa'
]

# %%
df_cleaned = df[essential_columns]

# %%
df_cleaned.to_csv('cleaned_placement_data.csv', index=False)
print("Data cleaning complete. 'cleaned_placement_data.csv' created with essential features.")
# Out:
# Data cleaning complete. 'cleaned_placement_data.csv' created with essential features.
